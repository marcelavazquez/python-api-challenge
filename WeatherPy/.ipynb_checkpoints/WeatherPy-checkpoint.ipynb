# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for OpenWeatherMap API call
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = 'metric'

url_request = f"{url}appid={weather_api_key}&units={unit}&q=" 


# weather_response = requests.get(url_request)
# print(weather_response)

# %%
# Make empty lists to store the data
cityname = []
lat = []
lng = []
date = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []

record = 0
sets = 1

print("Beginning Data Retrieval")
print("-----------------------------")

# Iterate through the cities

# JSON returns data from cities laid within definite circle that is specified by 
# center point ('lat', 'lon') and expected number of cities ('cnt') 
# around this point. The default number of cities is 10, the maximum is 50.
        

for city in cities:
    try:
        weather_response = requests.get(url_request+city).json()
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        humidity.append(weather_response["main"]["humidity"])
        cloudiness.append(weather_response["clouds"]["all"])
        wind_speed.append(weather_response["wind"]["speed"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        
        if record >= 49:
            record = 0
            sets += 1
            cityname.append(city)
        else:
            record += 1
            cityname.append(city)
        print(f"Processing Record {record} of Set {sets} | {city}")
        
    except Exception:
        print(f"City not found. Skipping...")

print("-------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | verkhnevilyuysk
# Processing Record 2 of Set 1 | vazante
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | raudeberg
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | the valley
# Processing Record 14 of Set 1 | college
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | abha
# Processing Record 17 of Set 1 | terra santa
# Processing Record 18 of Set 1 | isangel
# Processing Record 19 of Set 1 | atuona
# Processing Record 8 of Set 4 | solnechnyy
# Processing Record 9 of Set 4 | fare
# Processing Record 10 of Set 4 | bidhuna
# Processing Record 11 of Set 4 | samana
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | tiarei
# Processing Record 15 of Set 4 | cape town
# City not found. Skipping...
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | birao
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | altay
# Processing Record 20 of Set 4 | aklavik
# Processing Record 21 of Set 4 | champasak
# Processing Record 22 of Set 4 | brainerd
# Processing Record 23 of Set 4 | rio gallegos
# Processing Record 24 of Set 4 | naco
# Processing Record 25 of Set 4 | poum
# Processing Record 26 of Set 4 | camana
# Processing Record 27 of Set 4 | sydney
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | lorengau
# Processing Record 31 of Set 4 | tiznit
# Processing Record 32 of Set 4 | acarau
# Processing Record 33 of Set 4 | auki
# Processing Record 34 of Set 4 | umm lajj
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | yekaterinovka
# Processing Record 37 of Set 4 | islamkot
# Processing Record 38 of Set 4 | karpathos
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | richards bay
# Processing Record 41 of Set 4 | tautira
# City not found. Skipping...
# Processing Record 42 of Set 4 | saint george
# Processing Record 43 of Set 4 | geraldton
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | waounde
# Processing Record 46 of Set 4 | katsuura
# Processing Record 47 of Set 4 | general pico
# Processing Record 48 of Set 4 | qaanaaq
# Processing Record 49 of Set 4 | lazaro cardenas
# Processing Record 0 of Set 5 | chuy
# Processing Record 1 of Set 5 | oranjestad
# City not found. Skipping...
# Processing Record 2 of Set 5 | patea
# Processing Record 3 of Set 5 | dengzhou
# Processing Record 4 of Set 5 | walvis bay
# Processing Record 5 of Set 5 | ternate
# Processing Record 6 of Set 5 | malindi
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | kahului
# Processing Record 9 of Set 5 | anda
# City not found. Skipping...
# Processing Record 10 of Set 5 | carutapera
# Processing Record 11 of Set 5 | belen
# Processing Record 12 of Set 5 | glasgow
# Processing Record 13 of Set 5 | georgetown
# City not found. Skipping...
# Processing Record 14 of Set 5 | ko samui
# Processing Record 15 of Set 5 | bredasdorp
# Processing Record 16 of Set 5 | baykit
# Processing Record 17 of Set 5 | suileng
# Processing Record 18 of Set 5 | jaque
# City not found. Skipping...
# Processing Record 19 of Set 5 | esso
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | pangnirtung
# Processing Record 23 of Set 5 | muli
# Processing Record 24 of Set 5 | sisimiut
# Processing Record 25 of Set 5 | kwinana
# Processing Record 26 of Set 5 | kalety
# Processing Record 27 of Set 5 | iwanai
# Processing Record 28 of Set 5 | aswan
# Processing Record 29 of Set 5 | pacific grove
# Processing Record 30 of Set 5 | atambua
# Processing Record 31 of Set 5 | ananindeua
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | ust-tsilma
# Processing Record 34 of Set 5 | yulara
# Processing Record 35 of Set 5 | satipo
# City not found. Skipping...
# Processing Record 36 of Set 5 | mackay
# Processing Record 37 of Set 5 | bayangol
# City not found. Skipping...
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | vysokogornyy
# Processing Record 40 of Set 5 | montauban
# Processing Record 41 of Set 5 | gayny
# Processing Record 42 of Set 5 | korla
# Processing Record 43 of Set 5 | hudson bay
# Processing Record 44 of Set 5 | dhidhdhoo
# Processing Record 45 of Set 5 | gejiu
# Processing Record 46 of Set 5 | bhag
# Processing Record 47 of Set 5 | mao
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | bolobo
# Processing Record 0 of Set 6 | anori
# Processing Record 1 of Set 6 | haines junction
# Processing Record 2 of Set 6 | roma
# Processing Record 3 of Set 6 | paamiut
# City not found. Skipping...
# Processing Record 4 of Set 6 | makat
# City not found. Skipping...
# Processing Record 5 of Set 6 | kieta
# Processing Record 6 of Set 6 | grajau
# Processing Record 7 of Set 6 | nanakuli
# Processing Record 8 of Set 6 | san jose
# Processing Record 9 of Set 6 | chapais
# Processing Record 10 of Set 6 | vestmannaeyjar
# Processing Record 11 of Set 6 | fallon
# Processing Record 12 of Set 6 | luganville
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | belmonte
# Processing Record 16 of Set 6 | priboj
# Processing Record 17 of Set 6 | goderich
# City not found. Skipping...
# Processing Record 18 of Set 6 | talnakh
# City not found. Skipping...
# Processing Record 19 of Set 6 | riyadh
# Processing Record 20 of Set 6 | hunterville
# Processing Record 21 of Set 6 | honiara
# Processing Record 22 of Set 6 | eydhafushi
# Processing Record 23 of Set 6 | mulchen
# Processing Record 24 of Set 6 | mitsamiouli
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | kruisfontein
# Processing Record 27 of Set 6 | hualmay
# City not found. Skipping...
# Processing Record 28 of Set 6 | olot
# Processing Record 29 of Set 6 | bathsheba
# Processing Record 30 of Set 6 | puro
# Processing Record 31 of Set 6 | ghotki
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | awjilah
# Processing Record 34 of Set 6 | francisco sa
# Processing Record 35 of Set 6 | vanavara
# Processing Record 36 of Set 6 | gizo
# Processing Record 37 of Set 6 | bayamo
# Processing Record 38 of Set 6 | chulym
# Processing Record 39 of Set 6 | dunmore town
# Processing Record 40 of Set 6 | kashary
# Processing Record 41 of Set 6 | yumen
# Processing Record 42 of Set 6 | carhuaz
# Processing Record 43 of Set 6 | russell
# Processing Record 44 of Set 6 | altar
# Processing Record 27 of Set 9 | caravelas
# Processing Record 28 of Set 9 | mahbubabad
# Processing Record 29 of Set 9 | bubaque
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | porto novo
# Processing Record 32 of Set 9 | kresna
# Processing Record 33 of Set 9 | rovaniemi
# Processing Record 34 of Set 9 | baherden
# Processing Record 35 of Set 9 | mildura
# Processing Record 36 of Set 9 | porto santo
# Processing Record 37 of Set 9 | kudahuvadhoo
# Processing Record 38 of Set 9 | blagoyevo
# Processing Record 39 of Set 9 | japura
# Processing Record 40 of Set 9 | quang ngai
# Processing Record 41 of Set 9 | vardo
# Processing Record 42 of Set 9 | fairbanks
# Processing Record 43 of Set 9 | tabou
# City not found. Skipping...
# Processing Record 44 of Set 9 | vao
# Processing Record 45 of Set 9 | vila franca do campo
# Processing Record 46 of Set 9 | waipawa
# City not found. Skipping...
# Processing Record 47 of Set 9 | kailua
# Processing Record 48 of Set 9 | san ramon
# Processing Record 49 of Set 9 | letterkenny
# Processing Record 0 of Set 10 | odweyne
# Processing Record 1 of Set 10 | lagos
# Processing Record 2 of Set 10 | waynesville
# City not found. Skipping...
# Processing Record 3 of Set 10 | madimba
# Processing Record 4 of Set 10 | kloulklubed
# City not found. Skipping...
# Processing Record 5 of Set 10 | ziarat
# Processing Record 6 of Set 10 | sucua
# Processing Record 7 of Set 10 | dunedin
# City not found. Skipping...
# Processing Record 8 of Set 10 | hasaki
# Processing Record 9 of Set 10 | maniitsoq
# Processing Record 10 of Set 10 | sargatskoye
# Processing Record 11 of Set 10 | sesheke
# Processing Record 12 of Set 10 | sergeyevka
# Processing Record 13 of Set 10 | abong mbang
# Processing Record 14 of Set 10 | madang
# Processing Record 15 of Set 10 | iralaya
# Processing Record 16 of Set 10 | taber
# Processing Record 17 of Set 10 | gravdal
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | turukhansk
# Processing Record 20 of Set 10 | las lomas
# Processing Record 21 of Set 10 | manjacaze
# Processing Record 22 of Set 10 | tveit
# Processing Record 23 of Set 10 | bud
# Processing Record 24 of Set 10 | la cruz
# City not found. Skipping...
# Processing Record 25 of Set 10 | impfondo
# City not found. Skipping...
# Processing Record 26 of Set 10 | akureyri
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | grandola
# Processing Record 29 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 10 | colonial park
# Processing Record 31 of Set 10 | dmitriyevka
# Processing Record 32 of Set 10 | yueyang
# Processing Record 33 of Set 10 | kharan
# Processing Record 34 of Set 10 | lewistown
# Processing Record 35 of Set 10 | salamiyah
# Processing Record 36 of Set 10 | singapore
# Processing Record 37 of Set 10 | sulangan
# Processing Record 38 of Set 10 | acajutla
# Processing Record 39 of Set 10 | lebowakgomo
# Processing Record 40 of Set 10 | bilibino
# Processing Record 41 of Set 10 | port macquarie
# Processing Record 42 of Set 10 | santa luzia
# Processing Record 43 of Set 10 | khuzhir
# Processing Record 44 of Set 10 | coihueco
# Processing Record 45 of Set 10 | elk city
# Processing Record 46 of Set 10 | comodoro rivadavia
# Processing Record 47 of Set 10 | lata
# Processing Record 48 of Set 10 | cap malheureux
# Processing Record 49 of Set 10 | bilma
# Processing Record 0 of Set 11 | huilong
# Processing Record 1 of Set 11 | salta
# Processing Record 2 of Set 11 | yerbogachen
# Processing Record 3 of Set 11 | axim
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | batagay-alyta
# Processing Record 6 of Set 11 | tuy hoa
# Processing Record 7 of Set 11 | sabang
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | la macarena
# Processing Record 10 of Set 11 | donskoye
# Processing Record 11 of Set 11 | la spezia
# Processing Record 12 of Set 11 | novyy svit
# Processing Record 13 of Set 11 | panguipulli
# Processing Record 14 of Set 11 | pajan
# Processing Record 15 of Set 11 | neiafu
# Processing Record 16 of Set 11 | zmeinogorsk
# Processing Record 17 of Set 11 | maceio
# Processing Record 18 of Set 11 | bayeux
# Processing Record 19 of Set 11 | bam
# Processing Record 20 of Set 11 | surt
# Processing Record 21 of Set 11 | touros
# Processing Record 22 of Set 11 | kavos
# Processing Record 23 of Set 11 | kismayo
# Processing Record 24 of Set 11 | karratha
# Processing Record 25 of Set 11 | vaxjo
# Processing Record 26 of Set 11 | christiana
# Processing Record 27 of Set 11 | campbell river
# Processing Record 28 of Set 11 | seoul
# Processing Record 29 of Set 11 | port blair
# Processing Record 30 of Set 11 | waitati
# Processing Record 31 of Set 11 | ostersund
# Processing Record 32 of Set 11 | kashi
# Processing Record 33 of Set 11 | eyl
# Processing Record 34 of Set 11 | toora-khem
# Processing Record 35 of Set 11 | gangelt
# Processing Record 36 of Set 11 | pitsunda
# Processing Record 37 of Set 11 | san vicente
# Processing Record 38 of Set 11 | itoman
# Processing Record 39 of Set 11 | bassano
# Processing Record 40 of Set 11 | pointe michel
# Processing Record 41 of Set 11 | ripollet
# Processing Record 42 of Set 11 | taos
# Processing Record 43 of Set 11 | whitianga
# Processing Record 44 of Set 11 | ust-kuyga
# Processing Record 45 of Set 11 | boo
# Processing Record 46 of Set 11 | tripoli
# Processing Record 47 of Set 11 | puri
# Processing Record 48 of Set 11 | ormara
# Processing Record 49 of Set 11 | hot springs
# Processing Record 0 of Set 12 | mount isa
# City not found. Skipping...
# Processing Record 1 of Set 12 | gat
# -------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary
weather_dict = {
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed
}

# Create DataFrame

weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  verkhnevilyuysk          42      RU  1588989656        80  63.45  120.32
# 1          vazante          95      BR  1588989383        89 -17.99  -46.91
# 2   saint-philippe          54      RE  1588989203        53 -21.36   55.77
# 3           dikson          54      RU  1588989234        96  73.51   80.55
# 4   ribeira grande         100      PT  1588989658        92  38.52  -28.70
#
#    Max Temp  Wind Speed
# 0     -0.02        3.35
# 1     18.48        1.49
# 2     22.00        3.60
# 3     -3.72        8.36
# 4     17.40        8.38

# %%
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Max Temp",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Max Temperature (05/8/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Humidity",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Humidity (05/8/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsHum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Cloudiness",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Cloudiness (05/8/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Wind Speed",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Wind Speed (05/8/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsWind.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def line_reg_hw(x_values,y_values,x_desc,y_desc,x_ann,y_ann):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_ann,y_ann),fontsize=15,color="red")
    plt.xlabel(x_desc)
    plt.ylabel(y_desc)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"]>=0]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<0]

northern_hemisphere.head()
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   verkhnevilyuysk          42      RU  1588989656        80  63.45  120.32
# 3            dikson          54      RU  1588989234        96  73.51   80.55
# 4    ribeira grande         100      PT  1588989658        92  38.52  -28.70
# 7         raudeberg         100      NO  1588989658        90  61.99    5.14
# 12       the valley          20      AI  1588989202        74  18.22  -63.06
#
#     Max Temp  Wind Speed
# 0      -0.02        3.35
# 3      -3.72        8.36
# 4      17.40        8.38
# 7       5.00        5.48
# 12     28.00        5.10

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Max Temp"],
    "Latitude",
    "Temperature (Fahrenheit)",6,-10)

plt.savefig("NHLatvsTemp.png")
# Out:
# The r-squared is: -0.8525545160291217

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Max Temp"],
    "Latitude","Temperature (Fahrenheit)",
    -55,25)

plt.savefig("SHLatvsTemp.png")
# Out:
# The r-squared is: 0.6807254215444615

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Humidity"],
    "Latitude","Humidity",
    45,10)

plt.savefig("NHLatvsHum.png")
# Out:
# The r-squared is: 0.09489693630645585

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Humidity"],
    "Latitude","Humidity",
    -55,40)

plt.savefig("SHLatvsHum.png")
# Out:
# The r-squared is: 0.21358143269573868

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Cloudiness"],
    "Latitude","Cloudiness",
    40,30)

plt.savefig("NHLatvsCloud.png")
# Out:
# The r-squared is: 0.042150747747496865

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Cloudiness"],
    "Latitude","Cloudiness",
    -50,50)

plt.savefig("SHLatvsCloud.png")
# Out:
# The r-squared is: 0.2459452433103386

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Wind Speed"],
    "Latitude","Wind Speed",
    10,14)

plt.savefig("NHLatvsWind.png")
# Out:
# The r-squared is: 0.08756101708286512

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Wind Speed"],
    "Latitude","Wind Speed",
    -50,9)

plt.savefig("SHLatvsWind.png")
# Out:
# The r-squared is: -0.16714627650590524
