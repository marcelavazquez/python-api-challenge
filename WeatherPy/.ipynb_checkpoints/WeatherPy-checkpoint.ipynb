# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for OpenWeatherMap API call
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = 'metric'

url_request = f"{url}appid={weather_api_key}&units={unit}&q=" 


# weather_response = requests.get(url_request)
# print(weather_response)

# %%
# Make empty lists to store the data
cityname = []
lat = []
lng = []
date = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []

record = 0
sets = 1

print("Beginning Data Retrieval")
print("-----------------------------")

# Iterate through the cities

# JSON returns data from cities laid within definite circle that is specified by 
# center point ('lat', 'lon') and expected number of cities ('cnt') 
# around this point. The default number of cities is 10, the maximum is 50.
        

for city in cities:
    try:
        weather_response = requests.get(url_request+city).json()
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        humidity.append(weather_response["main"]["humidity"])
        cloudiness.append(weather_response["clouds"]["all"])
        wind_speed.append(weather_response["wind"]["speed"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        
        if record >= 49:
            record = 0
            sets += 1
            cityname.append(city)
        else:
            record += 1
            cityname.append(city)
        print(f"Processing Record {record} of Set {sets} | {city}")
        
    except Exception:
        print(f"City not found. Skipping...")

print("-------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | harstad
# Processing Record 3 of Set 1 | ambon
# Processing Record 4 of Set 1 | akyab
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | watsa
# Processing Record 7 of Set 1 | liwale
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | ami
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | bac lieu
# City not found. Skipping...
# Processing Record 15 of Set 1 | ourinhos
# City not found. Skipping...
# Processing Record 16 of Set 1 | bayir
# Processing Record 17 of Set 1 | itarema
# Processing Record 18 of Set 1 | wattegama
# Processing Record 19 of Set 1 | eyl
# Processing Record 20 of Set 1 | cidreira
# Processing Record 13 of Set 4 | urumqi
# City not found. Skipping...
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | cardston
# City not found. Skipping...
# Processing Record 17 of Set 4 | tanout
# Processing Record 18 of Set 4 | nantucket
# Processing Record 19 of Set 4 | srandakan
# Processing Record 20 of Set 4 | nyurba
# Processing Record 21 of Set 4 | samarai
# Processing Record 22 of Set 4 | quatre cocos
# Processing Record 23 of Set 4 | guanagazapa
# City not found. Skipping...
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | swellendam
# Processing Record 26 of Set 4 | mar del plata
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | luanda
# Processing Record 29 of Set 4 | kayerkan
# Processing Record 30 of Set 4 | san jose
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | florence
# Processing Record 33 of Set 4 | alvaro obregon
# Processing Record 34 of Set 4 | karaikkudi
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | uusikaupunki
# Processing Record 37 of Set 4 | caravelas
# Processing Record 38 of Set 4 | tabuk
# Processing Record 39 of Set 4 | mackay
# Processing Record 40 of Set 4 | gat
# Processing Record 41 of Set 4 | touros
# City not found. Skipping...
# Processing Record 42 of Set 4 | byron bay
# Processing Record 43 of Set 4 | chipoka
# Processing Record 44 of Set 4 | kingsville
# Processing Record 45 of Set 4 | atasu
# Processing Record 46 of Set 4 | manadhoo
# Processing Record 47 of Set 4 | itaituba
# Processing Record 48 of Set 4 | dekar
# Processing Record 49 of Set 4 | bati
# Processing Record 0 of Set 5 | luderitz
# Processing Record 1 of Set 5 | bandarbeyla
# Processing Record 2 of Set 5 | moerai
# Processing Record 3 of Set 5 | chabahar
# Processing Record 4 of Set 5 | champua
# Processing Record 5 of Set 5 | dhidhdhoo
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | dodola
# Processing Record 8 of Set 5 | sibut
# Processing Record 9 of Set 5 | cantagalo
# Processing Record 10 of Set 5 | sao gabriel da cachoeira
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | beringovskiy
# Processing Record 13 of Set 5 | charters towers
# Processing Record 14 of Set 5 | kaeo
# Processing Record 15 of Set 5 | siilinjarvi
# Processing Record 16 of Set 5 | anajatuba
# Processing Record 17 of Set 5 | kapaa
# City not found. Skipping...
# Processing Record 18 of Set 5 | opuwo
# Processing Record 19 of Set 5 | inuvik
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | aktau
# Processing Record 22 of Set 5 | paka
# Processing Record 23 of Set 5 | oistins
# Processing Record 24 of Set 5 | bredasdorp
# Processing Record 25 of Set 5 | luwuk
# Processing Record 26 of Set 5 | tessalit
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | chapais
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | ouango
# Processing Record 31 of Set 5 | noumea
# Processing Record 32 of Set 5 | okhotsk
# Processing Record 33 of Set 5 | maraa
# Processing Record 34 of Set 5 | tateyama
# Processing Record 35 of Set 5 | qaqortoq
# Processing Record 36 of Set 5 | sukhodol
# Processing Record 37 of Set 5 | sattenapalle
# Processing Record 38 of Set 5 | kidal
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | mumford
# Processing Record 41 of Set 5 | srednekolymsk
# Processing Record 42 of Set 5 | sinop
# Processing Record 43 of Set 5 | henties bay
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | hobart
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | mitsamiouli
# Processing Record 48 of Set 5 | lebu
# Processing Record 49 of Set 5 | portland
# Processing Record 0 of Set 6 | tuatapere
# Processing Record 1 of Set 6 | ribeira grande
# Processing Record 2 of Set 6 | gaeta
# Processing Record 3 of Set 6 | teahupoo
# Processing Record 4 of Set 6 | morondava
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | wagar
# Processing Record 7 of Set 6 | lushnje
# Processing Record 8 of Set 6 | cabo san lucas
# Processing Record 9 of Set 6 | kashi
# Processing Record 10 of Set 6 | zhongshan
# City not found. Skipping...
# Processing Record 11 of Set 6 | jieshi
# Processing Record 12 of Set 6 | falun
# Processing Record 13 of Set 6 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 14 of Set 6 | castro
# Processing Record 15 of Set 6 | griffith
# Processing Record 16 of Set 6 | panaba
# Processing Record 17 of Set 6 | bud
# Processing Record 18 of Set 6 | tokonou
# City not found. Skipping...
# Processing Record 19 of Set 6 | marystown
# Processing Record 20 of Set 6 | upernavik
# Processing Record 21 of Set 6 | martinsville
# Processing Record 22 of Set 6 | sa kaeo
# Processing Record 23 of Set 6 | narsaq
# City not found. Skipping...
# Processing Record 24 of Set 6 | ares
# Processing Record 25 of Set 6 | nara
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | santiago
# Processing Record 28 of Set 6 | northam
# Processing Record 29 of Set 6 | kiruna
# Processing Record 30 of Set 6 | arkhonskaya
# Processing Record 31 of Set 6 | bulgan
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | guarapari
# City not found. Skipping...
# Processing Record 34 of Set 6 | thompson
# Processing Record 35 of Set 6 | nushki
# Processing Record 36 of Set 6 | tucumcari
# Processing Record 37 of Set 6 | maniitsoq
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | artyom
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | serebryanyy bor
# Processing Record 42 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 6 | port-gentil
# City not found. Skipping...
# Processing Record 44 of Set 6 | kristiansund
# Processing Record 45 of Set 6 | jalhay
# City not found. Skipping...
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | sao felix do xingu
# Processing Record 49 of Set 6 | matamoros
# Processing Record 0 of Set 7 | shimoni
# Processing Record 1 of Set 7 | sawtell
# Processing Record 2 of Set 7 | sayyan
# City not found. Skipping...
# Processing Record 3 of Set 7 | campbell river
# Processing Record 4 of Set 7 | karratha
# Processing Record 5 of Set 7 | healesville
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | trapani
# Processing Record 8 of Set 7 | mount isa
# Processing Record 9 of Set 7 | soyo
# Processing Record 10 of Set 7 | scarborough
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | port elizabeth
# Processing Record 13 of Set 7 | arraial do cabo
# Processing Record 14 of Set 7 | guane
# Processing Record 15 of Set 7 | sompeta
# Processing Record 16 of Set 7 | hirara
# Processing Record 17 of Set 7 | barabinsk
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | jiutai
# Processing Record 20 of Set 7 | guymon
# Processing Record 21 of Set 7 | kiama
# Processing Record 22 of Set 7 | mudgee
# City not found. Skipping...
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | svetogorsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | adrar
# Processing Record 26 of Set 7 | vila franca do campo
# Processing Record 27 of Set 7 | pizarro
# Processing Record 28 of Set 7 | tilichiki
# City not found. Skipping...
# Processing Record 29 of Set 7 | kushima
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | chesma
# Processing Record 32 of Set 7 | tahe
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | alamogordo
# Processing Record 35 of Set 7 | victoria
# Processing Record 36 of Set 7 | puerto berrio
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | bow island
# Processing Record 39 of Set 7 | mangrol
# Processing Record 40 of Set 7 | sauga
# Processing Record 41 of Set 7 | bani walid
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | guiyang
# Processing Record 44 of Set 7 | anloga
# Processing Record 45 of Set 7 | roma
# Processing Record 46 of Set 7 | nishihara
# Processing Record 47 of Set 7 | peringat
# Processing Record 48 of Set 7 | bubaque
# Processing Record 49 of Set 7 | nemuro
# Processing Record 0 of Set 8 | iqaluit
# Processing Record 1 of Set 8 | muros
# Processing Record 2 of Set 8 | russell
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | mineiros
# City not found. Skipping...
# Processing Record 5 of Set 8 | chuy
# Processing Record 6 of Set 8 | adre
# City not found. Skipping...
# Processing Record 7 of Set 8 | gallneukirchen
# Processing Record 8 of Set 8 | darhan
# Processing Record 9 of Set 8 | rajampet
# Processing Record 10 of Set 8 | korhogo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 40 of Set 9 | aleksandro-nevskiy
# Processing Record 41 of Set 9 | krasnaya gorka
# Processing Record 42 of Set 9 | wenzhou
# Processing Record 43 of Set 9 | rio gallegos
# Processing Record 44 of Set 9 | tautira
# Processing Record 45 of Set 9 | prosvet
# Processing Record 46 of Set 9 | rorvik
# Processing Record 47 of Set 9 | marrakesh
# Processing Record 48 of Set 9 | steamboat springs
# City not found. Skipping...
# Processing Record 49 of Set 9 | fort nelson
# Processing Record 0 of Set 10 | nicoya
# Processing Record 1 of Set 10 | nhulunbuy
# Processing Record 2 of Set 10 | uvinza
# Processing Record 3 of Set 10 | schroeder
# Processing Record 4 of Set 10 | athabasca
# Processing Record 5 of Set 10 | urucara
# Processing Record 6 of Set 10 | badiraguato
# Processing Record 7 of Set 10 | gobabis
# Processing Record 8 of Set 10 | humaita
# Processing Record 9 of Set 10 | redmond
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | phalodi
# Processing Record 12 of Set 10 | yeppoon
# Processing Record 13 of Set 10 | olafsvik
# Processing Record 14 of Set 10 | boulder city
# Processing Record 15 of Set 10 | negotin
# Processing Record 16 of Set 10 | arlit
# Processing Record 17 of Set 10 | puerto baquerizo moreno
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | lewiston
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | savannah bight
# Processing Record 22 of Set 10 | chanika
# Processing Record 23 of Set 10 | hukuntsi
# Processing Record 24 of Set 10 | abu kamal
# Processing Record 25 of Set 10 | berekum
# Processing Record 26 of Set 10 | marang
# Processing Record 27 of Set 10 | paita
# Processing Record 28 of Set 10 | acapulco
# Processing Record 29 of Set 10 | hami
# Processing Record 30 of Set 10 | olinda
# Processing Record 31 of Set 10 | kaitangata
# Processing Record 32 of Set 10 | ranfurly
# Processing Record 33 of Set 10 | nikel
# Processing Record 34 of Set 10 | ostrovnoy
# Processing Record 35 of Set 10 | krasnozerskoye
# Processing Record 36 of Set 10 | shepsi
# Processing Record 37 of Set 10 | iralaya
# Processing Record 38 of Set 10 | jiwani
# Processing Record 39 of Set 10 | tupik
# Processing Record 40 of Set 10 | sensuntepeque
# Processing Record 41 of Set 10 | talnakh
# Processing Record 42 of Set 10 | davila
# Processing Record 43 of Set 10 | verkhnyaya inta
# Processing Record 44 of Set 10 | lufilufi
# Processing Record 45 of Set 10 | oudtshoorn
# Processing Record 46 of Set 10 | at-bashi
# Processing Record 47 of Set 10 | la romana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 10 | masunga
# Processing Record 49 of Set 10 | acarau
# Processing Record 0 of Set 11 | obo
# Processing Record 1 of Set 11 | bellevue
# Processing Record 2 of Set 11 | bemidji
# Processing Record 3 of Set 11 | ust-tsilma
# Processing Record 4 of Set 11 | kirakira
# Processing Record 5 of Set 11 | sao mateus do maranhao
# Processing Record 6 of Set 11 | huarmey
# Processing Record 7 of Set 11 | jhawarian
# Processing Record 8 of Set 11 | harwich
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | kautokeino
# Processing Record 11 of Set 11 | mentana
# City not found. Skipping...
# Processing Record 12 of Set 11 | the valley
# Processing Record 13 of Set 11 | togul
# Processing Record 14 of Set 11 | requena
# Processing Record 15 of Set 11 | khani
# Processing Record 16 of Set 11 | ambovombe
# Processing Record 17 of Set 11 | dangriga
# Processing Record 18 of Set 11 | araripina
# Processing Record 19 of Set 11 | bantacan
# Processing Record 20 of Set 11 | donja dubica
# Processing Record 21 of Set 11 | tabou
# Processing Record 22 of Set 11 | tura
# Processing Record 23 of Set 11 | svetlogorsk
# Processing Record 24 of Set 11 | chitral
# Processing Record 25 of Set 11 | povoa de varzim
# Processing Record 26 of Set 11 | taunggyi
# Processing Record 27 of Set 11 | rio de janeiro
# Processing Record 28 of Set 11 | redlands
# Processing Record 29 of Set 11 | jinchang
# Processing Record 30 of Set 11 | beruwala
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | saint george
# Processing Record 33 of Set 11 | palmas de monte alto
# Processing Record 34 of Set 11 | cuauhtemoc
# Processing Record 35 of Set 11 | lampazos de naranjo
# City not found. Skipping...
# Processing Record 36 of Set 11 | french harbor
# Processing Record 37 of Set 11 | itapuranga
# Processing Record 38 of Set 11 | laredo
# Processing Record 39 of Set 11 | labuhan
# Processing Record 40 of Set 11 | ende
# Processing Record 41 of Set 11 | daru
# Processing Record 42 of Set 11 | barentu
# Processing Record 43 of Set 11 | kibala
# Processing Record 44 of Set 11 | kismayo
# Processing Record 45 of Set 11 | sitka
# Processing Record 46 of Set 11 | igarka
# Processing Record 47 of Set 11 | mokhsogollokh
# Processing Record 48 of Set 11 | novopskov
# Processing Record 49 of Set 11 | uetze
# Processing Record 0 of Set 12 | maitum
# Processing Record 1 of Set 12 | kintinku
# Processing Record 2 of Set 12 | shache
# Processing Record 3 of Set 12 | can
# Processing Record 4 of Set 12 | itaueira
# Processing Record 5 of Set 12 | coihaique
# Processing Record 6 of Set 12 | nalbari
# Processing Record 7 of Set 12 | berlevag
# Processing Record 8 of Set 12 | auki
# City not found. Skipping...
# Processing Record 9 of Set 12 | burnie
# Processing Record 10 of Set 12 | domoni
# Processing Record 11 of Set 12 | stornoway
# Processing Record 12 of Set 12 | kaka
# Processing Record 13 of Set 12 | talaya
# City not found. Skipping...
# Processing Record 14 of Set 12 | coihueco
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | la paz
# Processing Record 17 of Set 12 | shu
# Processing Record 18 of Set 12 | tirumullaivasal
# Processing Record 19 of Set 12 | ostersund
# Processing Record 20 of Set 12 | samarinda
# Processing Record 21 of Set 12 | varnamo
# Processing Record 22 of Set 12 | timizart
# Processing Record 23 of Set 12 | akdepe
# -------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary
weather_dict = {
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed
}

# Create DataFrame

weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          573
# Cloudiness    573
# Country       573
# Date          573
# Humidity      573
# Lat           573
# Lng           573
# Max Temp      573
# Wind Speed    573
# dtype: int64

# %%
weather_df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0  rikitea          34      PF  1588970001        70 -23.12 -134.97     24.25
# 1  harstad         100      NO  1588970317        94  68.80   16.53      0.00
# 2    ambon           8      ID  1588970317        97  -3.70  128.18     26.67
# 3    akyab           0      MM  1588970317        75  20.15   92.90     27.05
# 4   albany         100      US  1588969929        27  42.60  -73.97     13.89
#
#    Wind Speed
# 0        3.24
# 1        2.60
# 2        5.77
# 3        3.57
# 4        1.70

# %%
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Max Temp",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Max Temperature (05/8/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Humidity",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Humidity (05/8/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsHum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Cloudiness",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Cloudiness (05/8/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Wind Speed",figsize=(6,4), marker='o', grid=True,edgecolors="black", title="City Latitude vs. Wind Speed (05/8/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.show()
plt.savefig("LatvsWind.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def line_reg_hw(x_values,y_values,x_desc,y_desc,x_ann,y_ann):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_ann,y_ann),fontsize=15,color="red")
    plt.xlabel(x_desc)
    plt.ylabel(y_desc)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"]>=0]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<0]

northern_hemisphere.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat    Lng  Max Temp  \
# 1   harstad         100      NO  1588970317        94  68.80  16.53      0.00
# 3     akyab           0      MM  1588970317        75  20.15  92.90     27.05
# 4    albany         100      US  1588969929        27  42.60 -73.97     13.89
# 5     watsa          99      CD  1588970318       100   3.04  29.54     19.25
# 7  tasiilaq          12      GL  1588970055        69  65.61 -37.64      1.00
#
#    Wind Speed
# 1        2.60
# 3        3.57
# 4        1.70
# 5        1.11
# 7        2.10

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Max Temp"],
    "Latitude",
    "Temperature (Fahrenheit)",6,-10)

plt.savefig("NHLatvsTemp.png")
# Out:
# The r-squared is: -0.8610493685730521

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Max Temp"],
    "Latitude","Temperature (Fahrenheit)",
    -55,23)

plt.savefig("SHLatvsTemp.png")
# Out:
# The r-squared is: 0.8086814012998718

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Humidity"],
    "Latitude","Humidity",
    45,15)

plt.savefig("NHLatvsHum.png")
# Out:
# The r-squared is: 0.14406606430870691

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Humidity"],
    "Latitude","Humidity",
    -55,10)

plt.savefig("SHLatvsHum.png")
# Out:
# The r-squared is: 0.14493494799655668

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Cloudiness"],
    "Latitude","Cloudiness",
    40,30)

plt.savefig("NHLatvsCloud.png")
# Out:
# The r-squared is: 0.12319880636726

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Cloudiness"],
    "Latitude","Cloudiness",
    -50,20)

plt.savefig("SHLatvsCloud.png")
# Out:
# The r-squared is: 0.12871878419115823

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_reg_hw(
    northern_hemisphere["Lat"],
    northern_hemisphere["Wind Speed"],
    "Latitude","Wind Speed",
    10,15)

plt.savefig("NHLatvsWind.png")
# Out:
# The r-squared is: 0.07398575810266393

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
line_reg_hw(
    southern_hemisphere["Lat"],
    southern_hemisphere["Wind Speed"],
    "Latitude","Wind Speed",
    -50,10)

plt.savefig("SHLatvsWind.png")
# Out:
# The r-squared is: -0.02449904262226144
